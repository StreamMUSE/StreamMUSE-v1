# %%
import os
from pathlib import Path
import glob
import json
import pretty_midi
import music21 as m21
from itertools import combinations
import numpy as np
import pandas as pd
import pretty_midi
import matplotlib.pyplot as plt
import seaborn as sns
import math
from tqdm import tqdm
import fluidsynth

import mido
import os
import tempfile
from midi2audio import FluidSynth
# Out:
# /home/ubuntu/ugrip/andrew/StreamMUSE/.venv/lib/python3.10/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
def layer_midis_with_midi2audio(midi_paths, output_wav_path, soundfont_path = '~/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3'):
    """
    Layers multiple MIDI files using Mido and converts the result to a
    WAV file using the midi2audio library.

    Args:
        midi_paths (list[str]): A list of paths for the MIDI files to layer.
        output_wav_path (str): The path for the final layered WAV file.
        soundfont_path (str): The path to your .sf2 or .sf3 SoundFont file.
    """
    if not midi_paths:
        print("Error: No MIDI file paths were provided.")
        return

    # 1. Combine MIDI files in memory with Mido
    print("Combining MIDI files with Mido...")
    # Load the first file as the base
    combined_midi = mido.MidiFile(midi_paths[0])

    # Append all tracks from the subsequent files
    for path in midi_paths[1:]:
        try:
            mid = mido.MidiFile(path)
            for track in mid.tracks:
                combined_midi.tracks.append(track)
        except Exception as e:
            print(f"Could not process {path}: {e}")
            continue
    
    # 2. Save the combined MIDI to a temporary file
    # Using a 'with' statement ensures the file is created and handled cleanly
    with tempfile.NamedTemporaryFile(suffix=".mid", delete=False) as tmp:
        temp_midi_path = tmp.name
        print(f"Saving combined MIDI to a temporary file: {temp_midi_path}")
        combined_midi.save(temp_midi_path)

    try:
        # 3. Convert the single temporary file to audio
        print("Converting temporary MIDI to WAV with midi2audio...")
        fs = FluidSynth(soundfont_path)
        fs.midi_to_audio(temp_midi_path, output_wav_path)
        print(f"✅ Success! Layered audio saved to: {output_wav_path}")

    finally:
        # 4. Clean up and delete the temporary file
        os.remove(temp_midi_path)
        print(f"Temporary file {temp_midi_path} deleted.")

# %%
dataset_paths = [
    # Raw inputs

    # 'inputs/pop909_dataset/mel',
    # 'inputs/aria_unique_skyline_top2/mel',

    # Ouputs
    # 'outputs/everything_0721/pop909_dataset/fake_offline_script',
    # 'outputs/everything_0721/aria_unique_skyline_top2/fake_offline_script',
    # 'outputs/everything_0721/pop909_dataset/fake_offline_script_lantency2',
    # 'outputs/everything_0721/aria_unique_skyline_top2/fake_offline_script_lantency2',
    # 'outputs/everything_0721/pop909_dataset/real_offline_script',
    # 'outputs/everything_0721/aria_unique_skyline_top2/real_offline_script',
    # 'outputs/everything_0721/pop909_dataset/real_offline_Xinyue_new_script',
    # 'outputs/everything_0721/aria_unique_skyline_top2/real_offline_Xinyue_new_script',

    # Samples
    '../prep_samples/aria/raw/',
    '../prep_samples/new_xinyue_with_chords/raw/',
]

# %%
# For aria samples
file_paths = sorted([Path(p) for p in glob.glob('*.mid', root_dir=dataset_paths[0]) if 'mel' in p])
file_paths = [Path(dataset_paths[0]) / Path(fp) for fp in file_paths]
file_paths
# Out:
# [PosixPath('../prep_samples/aria/raw/Batch_0_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_10_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_11_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_12_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_13_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_14_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_15_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_16_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_1_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_2_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_3_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_4_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_5_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_6_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_7_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_8_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/Batch_9_mel.mid'),
#  PosixPath('../prep_samples/aria/raw/epoch_0_mel.mid')]

# %%
# for p in file_paths:
#     mel = p 
#     acc = Path(str(p).replace('mel', 'acc'))
#     out = Path(str(p).replace('mel', 'wav').replace('.mid', '.wav'))
#     layer_midis_with_midi2audio([mel, acc], out)

# %%
dataset_paths[1]
# Out:
# '../prep_samples/new_xinyue_with_chords/raw/'

# %%
# For aria samples
file_paths = sorted([Path(p) for p in glob.glob('*.mid', root_dir=dataset_paths[1]) if 'mel' in p])
file_paths = [Path(dataset_paths[1]) / Path(fp) for fp in file_paths]
file_paths
# Out:
# [PosixPath('../prep_samples/new_xinyue_with_chords/raw/0_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/10_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/11_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/12_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/13_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/14_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/15_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/16_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/17_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/18_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/19_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/1_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/20_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/21_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/22_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/23_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/24_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/25_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/26_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/27_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/28_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/29_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/2_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/30_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/31_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/3_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/4_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/5_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/6_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/7_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/8_mel.mid'),
#  PosixPath('../prep_samples/new_xinyue_with_chords/raw/9_mel.mid')]

# %%
# For xinyue with chords (pop909)
for p in file_paths:
    mel = p 
    acc = Path(str(p).replace('mel', 'acc'))
    cho = Path(str(p).replace('mel', 'cho'))
    out = Path(str(p).replace('mel', 'wav').replace('.mid', '.wav'))
    layer_midis_with_midi2audio([mel, acc, cho], out)
# Out:
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpsdocgwms.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/0_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/0_wav.wav
# Temporary file /tmp/tmpsdocgwms.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmp3bajxrk1.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/10_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/10_wav.wav
# Temporary file /tmp/tmp3bajxrk1.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpsdiqyxro.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/11_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/11_wav.wav
# Temporary file /tmp/tmpsdiqyxro.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmp7kf_z9y5.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/12_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/12_wav.wav
# Temporary file /tmp/tmp7kf_z9y5.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmph5x002xr.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/13_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/13_wav.wav
# Temporary file /tmp/tmph5x002xr.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmp33fyp40q.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/14_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/14_wav.wav
# Temporary file /tmp/tmp33fyp40q.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpd7k8rie3.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/15_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/15_wav.wav
# Temporary file /tmp/tmpd7k8rie3.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpsbxg57uz.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/16_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/16_wav.wav
# Temporary file /tmp/tmpsbxg57uz.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpmny502sq.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/17_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/17_wav.wav
# Temporary file /tmp/tmpmny502sq.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpwi_z0gvo.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/18_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/18_wav.wav
# Temporary file /tmp/tmpwi_z0gvo.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmp4ey8thlk.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/19_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/19_wav.wav
# Temporary file /tmp/tmp4ey8thlk.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmp8615ngf1.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/1_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/1_wav.wav
# Temporary file /tmp/tmp8615ngf1.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpwaz5idrl.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/20_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/20_wav.wav
# Temporary file /tmp/tmpwaz5idrl.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpn8xkhtqp.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/21_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/21_wav.wav
# Temporary file /tmp/tmpn8xkhtqp.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmp5ms1iot5.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/22_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/22_wav.wav
# Temporary file /tmp/tmp5ms1iot5.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpjha4_cqh.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/23_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/23_wav.wav
# Temporary file /tmp/tmpjha4_cqh.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpkjjbyqsh.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/24_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/24_wav.wav
# Temporary file /tmp/tmpkjjbyqsh.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmphbpqng9a.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/25_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/25_wav.wav
# Temporary file /tmp/tmphbpqng9a.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpn12i7rdp.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/26_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/26_wav.wav
# Temporary file /tmp/tmpn12i7rdp.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpvea0_iw8.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/27_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/27_wav.wav
# Temporary file /tmp/tmpvea0_iw8.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmp_e84qyp8.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/28_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/28_wav.wav
# Temporary file /tmp/tmp_e84qyp8.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpd2ydnyn3.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/29_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/29_wav.wav
# Temporary file /tmp/tmpd2ydnyn3.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmppsbjwc16.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/2_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/2_wav.wav
# Temporary file /tmp/tmppsbjwc16.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpz1xfgm02.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/30_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/30_wav.wav
# Temporary file /tmp/tmpz1xfgm02.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpkdtwx4ia.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/31_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/31_wav.wav
# Temporary file /tmp/tmpkdtwx4ia.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpvmd4koav.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/3_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/3_wav.wav
# Temporary file /tmp/tmpvmd4koav.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpa0wkjz1p.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/4_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/4_wav.wav
# Temporary file /tmp/tmpa0wkjz1p.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmp00l_yso8.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/5_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/5_wav.wav
# Temporary file /tmp/tmp00l_yso8.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpeikugkhi.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/6_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/6_wav.wav
# Temporary file /tmp/tmpeikugkhi.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpdhc0mg7b.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/7_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/7_wav.wav
# Temporary file /tmp/tmpdhc0mg7b.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmp0i2bjos0.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/8_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/8_wav.wav
# Temporary file /tmp/tmp0i2bjos0.mid deleted.
# Combining MIDI files with Mido...
# Saving combined MIDI to a temporary file: /tmp/tmpdspm31et.mid
# Converting temporary MIDI to WAV with midi2audio...
# fluidsynth: error: fluid_is_soundfont(): fopen() failed: 'File does not exist.'
# Parameter '/home/ubuntu/home/ubuntu/ugrip/andrew/StreamMUSE/inference_benchmark/FluidR3Mono_GM.sf3' not a SoundFont or MIDI file or error occurred identifying it.
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file '../prep_samples/new_xinyue_with_chords/raw/9_wav.wav'..
# ✅ Success! Layered audio saved to: ../prep_samples/new_xinyue_with_chords/raw/9_wav.wav
# Temporary file /tmp/tmpdspm31et.mid deleted.
